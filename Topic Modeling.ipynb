# %%
# !pip3 install -U gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/2b/e0/fa6326251692056dc880a64eb22117e03269906ba55a6864864d24ec8b4e/gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2MB)
#     100% |████████████████████████████████| 24.2MB 41kB/s  eta 0:00:01    59% |███████████████████             | 14.4MB 5.7MB/s eta 0:00:02
# Collecting numpy>=1.11.3 (from gensim)
#   Using cached https://files.pythonhosted.org/packages/45/b2/6c7545bb7a38754d63048c7696804a0d947328125d81bf12beaa692c3ae3/numpy-1.19.5-cp36-cp36m-manylinux1_x86_64.whl
# Collecting scipy>=0.18.1 (from gensim)
#   Using cached https://files.pythonhosted.org/packages/c8/89/63171228d5ced148f5ced50305c89e8576ffc695a90b58fe5bb602b910c2/scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/ea/54/01525817b6f31533d308968b814999f7e666b2234f39a55cbe5de7c1ff99/smart_open-4.1.2-py3-none-any.whl (111kB)
#     100% |████████████████████████████████| 112kB 3.5MB/s eta 0:00:01
# Collecting six>=1.5.0 (from gensim)
#   Using cached https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Installing collected packages: numpy, scipy, smart-open, six, gensim
# Successfully installed gensim-3.8.3 numpy-1.19.5 scipy-1.5.4 six-1.15.0 smart-open-4.1.2

# %%
# Import modules
import os
import re
import pickle
import itertools
import numpy as np
import pandas as pd
from collections import Counter
from tqdm import tqdm_notebook
from gensim import corpora, models
import string

# NLP modules
from konlpy.tag import Mecab, Okt
from khaiii import khaiii

# Visualization modules
import seaborn as sns
import matplotlib.pyplot as plt

# Factor Analysis (PCA)
from sklearn.decomposition import PCA

# Chi square test
from scipy.stats import chi2_contingency

# Visualization setting
sns.set(style="ticks", palette="Set1")
plt.rcParams["font.family"] = 'NanumGothic'

# %%
def read_documents(input_file_name):
    corpus = []
#     with open(input_file_name, 'rb') as f:
#         temp_corpus=pickle.load()
        
#     for page in temp_corpus:
#         corpus += page
        
    return corpus
    
def text_cleaning(docs):
    # 한국어를 제외한 글자 제거 함수
    cleaned_docs = []
    
    for doc in docs:
        temp_doc = re.sub('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', str(doc))
        cleaned_docs.append(temp_doc)
    return cleaned_docs

def define_stopwords(path):
    SW = set()
    # 불용어 추가
    for i in string.punctuation:
        SW.add(i)
        
    with open(path, 'rb') as f:
        for word in f:
            SW.add(word)
            
    return SW

def text_tokenizing(corpus, tokenizer):
    # 명사 추출/ 형태소 분석
    mecab = Mecab()
    token_corpus = []
    
    if tokenizer == "noun":
        for n in tqdm_notebook(range(len(corpus)), desc = "PreProcessing"):
            token_text = mecab.nouns(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            
            token_corpus.append(token_text)
            
    elif tokenized == "morph":
        for n in tqdm_notebook(range(len(corpus)), desc = "PreProcessing"):
            token_text = mecab.morphs(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
            
    elif tokenized == "word":
        for n in tqdm_notebook(range(len(corpus)), desc = "PreProcessing"):
            token_text = corpus[n].split()
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
        
    return token_corpus

# %%
#Read Data
original_dat = pd.read_csv('./results_crawl.csv')
comp1_topic = original_dat[original_dat['company']=='더팩트']['text'].dropna().tolist()
SW = define_stopwords('stopwords-ko.txt')
cleaned_text = text_cleaning(comp1_topic)
tokenized_text = text_tokenizing(cleaned_text, tokenizer="noun")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# PreProcessing:   0%|          | 0/250 [00:00<?, ?it/s]

# %%
print(tokenized_text[0])
# Out:
# ['대전', '동부', '경찰서', '아동', '청소년', '보호', '법률', '위반', '혐의', '고교', '기간제', '교사', '여성', '구속', '송치', '유필', '제공', '경찰', '교사', '지위', '이용', '성범죄', '판단', '윤용', '기자', '대전', '고등학교', '여교사', '남학생', '제자', '관계', '형사', '처벌', '처지', '사건', '남학생', '해당', '여교사', '관계', '폭로', '대전', '동부', '경찰서', '아동', '청소년', '보호', '법률', '위반', '혐의', '고교', '기간제', '교사', '여성', '구속', '송치', '경찰', '지난해', '자신', '근무', '고등학교', '제자', '대전', '모텔', '관계', '혐의', '학교', '상담', '사실', '다만', '진술', '실제', '처벌', '미지', '수다', '경찰', '조사', '성폭행', '상반', '주장', '경찰', '교사', '지위', '이용해', '관계', '판단', '사건', '검찰', '사건', '학교', '직후', '사직서', '제출', '경찰', '관계자', '사안', '구체', '내용', '확인', '공연', '비하인드', '사진', '방법', '가입', '아이돌', '순위', '스타', '투표', '저작', '특종', '무단', '전재', '배포', '금지']

# %%
dictionary = corpora.Dictionary(tokenized_text)
corpus = [dictionary.doc2bow(text) for text in tokenized_text]

# %%
print(dictionary)
# Out:
# Dictionary(7477 unique tokens: ['가입', '검찰', '경찰', '경찰서', '고교']...)

# %%
corpus[0][:5]
# Out:
# [(0, 1), (1, 1), (2, 5), (3, 2), (4, 2)]

# %%
tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]
corpus_tfidf[0]
# Out:
# [(1, 0.030687277126903743),
#  (2, 0.25062180056891736),
#  (3, 0.14069467761325147),
#  (4, 0.1862601884155591),
#  (5, 0.1550387798751212),
#  (7, 0.18805203700063233),
#  (8, 0.02711525621807379),
#  (9, 0.35241827968887174),
#  (10, 0.08605653369577423),
#  (11, 0.05473663453640678),
#  (12, 0.0665850326385445),
#  (14, 0.24870300549643487),
#  (15, 9.026659633116386e-05),
#  (16, 0.24870300549643487),
#  (17, 0.031041953522143298),
#  (18, 0.1087407984779985),
#  (19, 0.23702414688683673),
#  (20, 0.12108665823589898),
#  (21, 0.1087407984779985),
#  (23, 0.09960912187007279),
#  (26, 0.09402601850031617),
#  (27, 0.08254491422312218),
#  (29, 0.10108380740332731),
#  (30, 0.035800948239804835),
#  (31, 0.06336218904407329),
#  (32, 0.09960912187007279),
#  (34, 0.08399841759985383),
#  (35, 0.12435150274821744),
#  (36, 0.06336218904407329),
#  (37, 0.07486674099192812),
#  (38, 0.24870300549643487),
#  (39, 0.1087407984779985),
#  (42, 0.056883161381780054),
#  (43, 0.12983202201642732),
#  (45, 0.24870300549643487),
#  (46, 0.1074710296083965),
#  (47, 0.09120991585696214),
#  (48, 0.1087407984779985),
#  (49, 0.04851499808293695),
#  (50, 0.05185763709621845),
#  (51, 0.09313009420777955),
#  (52, 0.04364533245149023),
#  (55, 0.026816954034085193),
#  (56, 0.19921824374014557),
#  (57, 0.05473663453640678),
#  (58, 0.02965557831920928),
#  (59, 0.03140230497993913),
#  (60, 0.020862577050336416),
#  (61, 0.14498773130399797),
#  (62, 0.056883161381780054),
#  (63, 0.059256036721709184),
#  (64, 0.133170065277089),
#  (65, 0.12435150274821744),
#  (66, 0.1550387798751212),
#  (69, 0.07072724819621318),
#  (70, 0.08052671527843262),
#  (71, 0.14498773130399797),
#  (72, 0.030687277126903743),
#  (73, 0.09530554820153259),
#  (74, 0.055784334400287953),
#  (75, 0.03140230497993913)]

# %%
model = models.ldamodel.LdaModel(corpus, num_topics=3, id2word=dictionary)

# %%
model.show_topic(0, 10)
# Out:
# [('로또', 0.014351159),
#  ('당첨', 0.011130583),
#  ('번호', 0.010881089),
#  ('복권', 0.008077438),
#  ('기자', 0.007732418),
#  ('서울', 0.007702239),
#  ('판매점', 0.006598958),
#  ('대통령', 0.00644859),
#  ('의원', 0.005309927),
#  ('검찰', 0.0049346923)]

# %%
NUM_TOPICS = 3
NUM_TOPIC_WORDS = 30

def build_doc_term_mat(documents):
    print("Building document-term matrix.")
    dictionary = corpora.Dictionary(documents)
    corpus = [dictionary.doc2bow(document) for document in documents]
    
    return corpus, dictionary

def print_topic_words(model):
    print("\nPrinting topic words.")
    for topic_id in range(model.num_topics):
        topic_word_probs = model.show_topic(topic_id, NUM_TOPIC_WORDS)
        print("Topic ID: {}".format(topic_id))
        
        for topic_word, prob in topic_word_probs:
            print("\t{}\t{}".format(topic_word, prob))
            
        print("\n")

# %%
corpus, dictionary = build_doc_term_mat(tokenized_text)
model = models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary, alpha="auto", eta="auto")
print_topic_words(model)
# Out:
# Building document-term matrix.
#
# Printing topic words.
# Topic ID: 0
# 	대통령	0.006458444986492395
# 	기자	0.006270280573517084
# 	의원	0.005691975355148315
# 	검찰	0.004489465616643429
# 	금지	0.004321454558521509
# 	코로나	0.003944133874028921
# 	사진	0.003918851725757122
# 	방법	0.003896558890119195
# 	민주당	0.003819718724116683
# 	서울	0.0035866815596818924
# 	혐의	0.0033416009973734617
# 	아이돌	0.0033056919928640127
# 	주택	0.003245334839448333
# 	수사	0.0032406356185674667
# 	국민	0.0031968061812222004
# 	선고	0.003151848679408431
# 	가입	0.0030638815369457006
# 	무단	0.0030092899687588215
# 	관련	0.002996420953422785
# 	공연	0.00299412221647799
# 	배포	0.00298882438801229
# 	비하인드	0.002974020317196846
# 	투표	0.002950745401903987
# 	후보	0.002942788414657116
# 	저작	0.002906152280047536
# 	지난해	0.002830454846844077
# 	순위	0.0026695493143051863
# 	총장	0.0026424552779644728
# 	삼성전자	0.0026280907914042473
# 	사건	0.002596677979454398
#
#
# Topic ID: 1
# 	의원	0.008067059330642223
# 	기자	0.007271035574376583
# 	서울	0.006608653347939253
# 	장관	0.005729539319872856
# 	사진	0.005277465097606182
# 	국민	0.005123837850987911
# 	대통령	0.005098339170217514
# 	로또	0.005013304762542248
# 	검찰	0.00501093128696084
# 	금지	0.004721785429865122
# 	당첨	0.004605052061378956
# 	코로나	0.004184337332844734
# 	스타	0.004103404004126787
# 	총장	0.0038885201793164015
# 	번호	0.0038512926548719406
# 	비하인드	0.0038225543685257435
# 	수사	0.0037240306846797466
# 	복권	0.003695671446621418
# 	무단	0.0036641249898821115
# 	순위	0.0036191607359796762
# 	배포	0.0035051952581852674
# 	관련	0.0034307194873690605
# 	전재	0.003390476107597351
# 	투표	0.0033650891855359077
# 	검사	0.0033562227617949247
# 	공연	0.00333395809866488
# 	가입	0.0032843188382685184
# 	민주당	0.0032720682211220264
# 	아이돌	0.00327015807852149
# 	정부	0.00326724024489522
#
#
# Topic ID: 2
# 	로또	0.01893431507050991
# 	당첨	0.013388331048190594
# 	번호	0.012519178912043571
# 	복권	0.009507526643574238
# 	기자	0.008211754262447357
# 	판매점	0.00666287075728178
# 	자동	0.00628487067297101
# 	서울	0.005985659547150135
# 	지역	0.00540037639439106
# 	대통령	0.00537106953561306
# 	금지	0.0053115105256438255
# 	수동	0.004821069538593292
# 	동행	0.004752978216856718
# 	의원	0.004401740618050098
# 	당첨금	0.0041919066570699215
# 	검찰	0.0036832778714597225
# 	게임	0.0035608503967523575
# 	회차	0.003557491349056363
# 	장관	0.003429285017773509
# 	국민	0.003382897935807705
# 	가입	0.0033760301303118467
# 	방법	0.0033496480900794268
# 	사진	0.0033402079716324806
# 	추첨	0.0032410286366939545
# 	저작	0.0032314376439899206
# 	특종	0.0031973812729120255
# 	코로나	0.0031910135876387358
# 	순위	0.0030822132248431444
# 	전재	0.0030733938328921795
# 	경기	0.003062681294977665

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
data = pyLDAvis.gensim.prepare(model, corpus, dictionary)
pyLDAvis.display(data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el331400155453381608571906685"></div>
# <script type="text/javascript">
#
# var ldavis_el331400155453381608571906685_data = {"mdsDat": {"x": [-0.0012565033963673092, -0.034234083687689695, 0.035490587084057], "y": [0.010461946455481149, -0.005513774231497728, -0.004948172223983407], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [47.776200273495114, 27.41895502165952, 24.804844704845365]}, "tinfo": {"Term": ["\ub85c\ub610", "\ub2f9\ucca8", "\ubc88\ud638", "\ubcf5\uad8c", "\ud310\ub9e4\uc810", "\uc790\ub3d9", "\uc218\ub3d9", "\ub3d9\ud589", "\ub2f9\ucca8\uae08", "\ud68c\ucc28", "\uac8c\uc784", "\ucd94\ucca8", "\uc9c0\uc5ed", "\ub2f9\ucca8\uc790", "\uad6c\ub9e4", "\uc0bc\uc131\uc804\uc790", "\uc120\uace0", "\ub300\ud1b5\ub839", "\ucd9c\uc810", "\uc8fc\ud0dd", "\ub300\ubc15", "\ubaa8\ub378", "\uc870\ud68c", "\uae30\uc790", "\uc77c\uce58", "\ubcf4\ub108\uc2a4", "\uace0\uc815", "\ubc29\ubc95", "\uc8fc\uc778\uacf5", "\uad6d\ud68c\uc758\uc6d0", "\uae40\ubd09\ud604", "\ud68c\uc0dd", "\ud5ec\uc2a4\ud074\ub7fd", "\uc774\uc801", "\uac80\uccb4", "\ud3d0\uae30", "\ub300\ud589", "\uc6b4\uc6b4", "\ub9c8\uadf8\ub098", "\uc6d0\uc804", "\uc785\uad6d", "\uc131\ub0a8", "\uc811\ub300", "\ud22c\uc5b4", "\uc0ac\ub9dd\uc790", "\uc601\uad6d", "\ud574\uc678", "\uae30\uc628", "\uc2a4\uc5d0", "\uae40\uc601\ub780", "\ub514\ud53c\uc528", "\uba74\uc138\uc810", "\uc774\ud504\ub85c", "\ubbf8\uc138\uba3c\uc9c0", "\ubc1c\uc804\uc18c", "\ub0b4\ub2ec", "\uc5f0\uc2b5\uc7a5", "\ubd81\ud55c", "\ubd84\ud560", "\uace0\uac80", "\uac80\uc0ac", "\uc2e0\uc6a9", "\uc811\uc885", "\uc911\uc18c", "\ubc29\uc5ed", "\ub300\ucd9c", "\uc7ac\ub09c", "\ub3d9\ubd80", "\uc7a5\uad00", "\uc804\uc790", "\uad6c\uce58\uc18c", "\ud655\uc9c4", "\ub2e8\uc77c", "\uc758\uc6d0", "\ub300\ucc45", "\ud68c\uc7a5", "\uad6d\ubbfc", "\uc2a4\ud0c0", "\uc0ac\uc9c4", "\uc11c\uc6b8", "\uc2e4\uc7a5", "\uccad\uc640\ub300", "\ucd1d\uc7a5", "\ube44\ud558\uc778\ub4dc", "\uc815\ubd80", "\uc2e0\uccad", "\uc778\uc0ac", "\uac80\ucc30", "\ubb34\ub2e8", "\uc9c0\uc6d0", "\uc758\ud639", "\uc218\uc0ac", "\uc774\ub0a0", "\uad00\ub828", "\uae30\uc790", "\ub300\ud45c", "\uc0ac\uac74", "\ucf54\ub85c\ub098", "\uc21c\uc704", "\ubc30\ud3ec", "\uc804\uc7ac", "\uae08\uc9c0", "\ub300\ud1b5\ub839", "\uc2dc\uc7a5", "\uacf5\uc5f0", "\ud22c\ud45c", "\ubbfc\uc8fc\ub2f9", "\ud2b9\uc885", "\ub2f9\ucca8", "\ub85c\ub610", "\ubcf5\uad8c", "\uc544\uc774\ub3cc", "\ubc88\ud638", "\uac00\uc785", "\ubc18\uc790\ub3d9", "\ubc30\ucd9c", "\uae30\uae08\ubc95", "\ub85c\ub610", "\ubbfc\ud638", "\ud68c\ucc28", "\ubd80\ub450", "\uc81c\uc8fc\ud56d", "\ucd94\ucca8", "\uad6c\uac00", "\ud640\ud2b8", "\ud589\uc6b4", "\uc8fc\uc778\uacf5", "\uae30\uc5fc", "\ub3d9\uba85", "\uba85\ubc18", "\ubc88\ud638", "\ub2e4\ud68c", "\ubd80\ud1b5\ub839", "\ud39c\uc2a4", "\uc138\uc885", "\ub2f9\ucca8\uc790", "\uac15\ud604", "\uc218\ub3d9", "\uc0c1\ub2f4\uc6d0", "\ube44\ub840", "\ub3d9\ud589", "\ub2f9\ucca8", "\uc81c\ud68c", "\ube44\ud2b8\ucf54\uc778", "\uc77c\uce58", "\ud310\ub9e4\uc810", "\ubcf5\uad8c", "\uc790\ub3d9", "\uac8c\uc784", "\uace0\uc815", "\ub2f9\ucca8\uae08", "\uc870\ud68c", "\uc804\ubd81", "\ub300\ubc15", "\ucd9c\uc810", "\uad6c\ub9e4", "\uc9c0\uc5ed", "\ubcf4\ub108\uc2a4", "\uae30\uc790", "\uacf5\ub9e4\ub3c4", "\uc2dc\ub3c4", "\uae08\uc9c0", "\uc11c\uc6b8", "\uacb0\uacfc", "\uacbd\uae30", "\uc774\ubc88", "\ub300\ud1b5\ub839", "\uc9c0\uae09", "\ubb38\uc81c", "\uc0ac\uc5c5", "\uac00\uc785", "\ubc29\ubc95", "\uc800\uc791", "\ud2b9\uc885", "\uc758\uc6d0", "\uac80\ucc30", "\uc804\uc7ac", "\uc7a5\uad00", "\uad6d\ubbfc", "\uc0ac\uc9c4", "\ucf54\ub85c\ub098", "\uc21c\uc704", "\uc790\uaca9\uc0c1\uc2e4", "\uac00\ubc29", "\ucc38\uc5ec\uc5f0\ub300", "\ud65c\ub3d9\ube44", "\uc131\uc528", "\uc774\uc900\uba85", "\uae40\uad00\uad6c", "\uc131\ubaa8", "\uae30\ub3c4\uc6d0", "\ud130\ubcf4", "\ud638\uac00", "\ucfe0\ud398", "\ud14d\uc0ac\uc2a4", "\ubaa8\ub354", "\ubc94\uc815", "\ub300\ub9cc", "\uc9c4\uc8fc", "\uc99d\uad8c\uac00", "\ub9cc\uc778", "\uc790\ub370", "\ud0a4\uc6c0\uc99d\uad8c", "\uc870\ub871", "\uc560\ub9ac\uc870", "\ubb38\ud615", "\ud568\uc ...
